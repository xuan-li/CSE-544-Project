# %%
from matplotlib import pyplot as plt
import seaborn as sns
from collections import Counter
from datetime import datetime
import os
from tqdm import tqdm_notebook as tqdm
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import re
import os

# %%
def get_lemma_distribution(file_name):
    lemmas=[]
    pattern = re.compile('http://en.wikipedia.org/wiki/[a-z,A-z,_]+$')
    for line in open(file_name):
        url=line.strip().split(' ')[2]
        if not pattern.match(url):
            continue
        lemma=url[url.rfind('/')+1:]
        if '.' in lemma:
            continue
        lemmas.append(lemma)
    return lemmas

# %%
lemmas=[]
f=open('./data/list1.txt')
f.readline()
for line in tqdm(f):
    line=line.strip()[:-3]
    l=get_lemma_distribution('./data/only_lemma/%s'%line)
    lemmas+=l
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
len(lemmas)
# Out:
# 7768098

# %%
counter=dict(Counter(lemmas))

# %%
counter['IPhone']
# Out:
# 761

# %%
max(counter.values())
# Out:
# 21465

# %%
scounter=sorted(counter.items(), key=lambda x:x[1], reverse=True)

# %%
scounter
# Out:
# [('Main_Page', 382910),
#  ('Wiki', 11840),
#  ('International_Talk_Like_a_Pirate_Day', 10112),
#  ('Ireland', 7452),
#  ('United_States', 6218),
#  ('Wikipedia', 4449),
#  ('Jena_Six', 3018),
#  ('Skull_and_Bones', 2886),
#  ('Naruto', 2834),
#  ('MySpace', 2604),
#  ('HTTP', 2600),
#  ('Vanessa_Hudgens', 2546),
#  ('Sex', 2436),
#  ('Blackwater_USA', 2251),
#  ('List_of_Family_Guy_episodes', 2146),
#  ('Kanye_West', 2138),
#  ('Northwest_Passage', 1923),
#  ('Colin_McRae', 1908),
#  ('YouTube', 1855),
#  ('Global_warming', 1826),
#  ('Pornography', 1755),
#  ('Robert_Jordan', 1717),
#  ('Cocaine', 1709),
#  ('Google', 1702),
#  ('Canada', 1692),
#  ('Autism', 1690),
#  ('Britney_Spears', 1664),
#  ('List_of_sex_positions', 1646),
#  ('World_War_II', 1618),
#  ('Japan', 1616),
#  ('India', 1610),
#  ('Phil_Spector', 1543),
#  ('Love', 1514),
#  ('Australia', 1513),
#  ('France', 1512),
#  ('United_Kingdom', 1506),
#  ('Nicole_Brown_Simpson', 1504),
#  ('Internet_Movie_Database', 1486),
#  ('Crushing', 1436),
#  ('Salem_witch_trials', 1395),
#  ('Penis', 1378),
#  ('Germany', 1374),
#  ('Facebook', 1365),
#  ('Whirlpool_Galaxy', 1353),
#  ('New_York_City', 1340),
#  ('China', 1298),
#  ('Jenny_McCarthy', 1279),
#  ('Yom_Kippur', 1272),
#  ('Politics', 1265),
#  ('List_of_countries', 1260),
#  ('Vanessa_Anne_Hudgens', 1242),
#  ('Anal_sex', 1234),
#  ('Standard_deviation', 1233),
#  ('Greater_Manchester', 1231),
#  ('Alan_Greenspan', 1222),
#  ('Sexual_intercourse', 1219),
#  ('Central_processing_unit', 1201),
#  ('United_States_Constitution', 1196),
#  ('Kanye_west', 1195),
#  ('Laser', 1181),
#  ('Vagina', 1165),
#  ('Aleister_Crowley', 1158),
#  ('Elisabeth_Hasselbeck', 1157),
#  ('Free_software', 1156),
#  ('Mexico', 1154),
#  ('Prison_Break', 1148),
#  ('List_of_Konoha_ninja', 1147),
#  ('United_states', 1146),
#  ('Leonardo_da_Vinci', 1146),
#  ('Periodic_table', 1142),
#  ('Ramadan', 1140),
#  ('Europe', 1138),
#  ('Adolf_Hitler', 1136),
#  ('England', 1127),
#  ('Zac_Efron', 1121),
#  ('Italy', 1118),
#  ('Masturbation', 1114),
#  ('Book', 1100),
#  ('WWE_No_Mercy', 1098),
#  ('World_War_I', 1098),
#  ('Christopher_Columbus', 1088),
#  ('Talk_like_a_pirate_day', 1086),
#  ('Crack_cocaine', 1083),
#  ('Mandatory_sign', 1082),
#  ('Internet', 1080),
#  ('Family_Guy', 1079),
#  ('List_of_Naruto_characters', 1069),
#  ('Islam', 1055),
#  ('Spain', 1053),
#  ('Naruto_Uzumaki', 1046),
#  ('Wii', 1043),
#  ('Russia', 1043),
#  ('George_Reeves', 1040),
#  ('Giles_Corey', 1035),
#  ('Earth', 1035),
#  ('Brazil', 1024),
#  ('Rihanna', 1021),
#  ('Tupac_Shakur', 1017),
#  ('President_of_the_United_States', 1014),
#  ('William_Shakespeare', 1010),
#  ('Floppy_disk', 1005),
#  ('Egypt', 1002),
#  ('London', 997),
#  ('Buddhism', 993),
#  ('Elvis_Presley', 990),
#  ('Bill_Gates', 987),
#  ('Beauty_and_the_Geek', 957),
#  ('Processor', 956),
#  ('Heroes', 943),
#  ('Data', 943),
#  ('American_Civil_War', 934),
#  ('Africa', 928),
#  ('Oj_simpson', 928),
#  ('List_of_female_porn_stars_by_decade', 927),
#  ('Eminem', 926),
#  ('If_I_Did_It', 922),
#  ('Superman', 900),
#  ('Proxy_server', 900),
#  ('Oral_sex', 899),
#  ('Wiktionary', 896),
#  ('Water', 893),
#  ('Soft', 891),
#  ('World_Wrestling_Entertainment', 891),
#  ('Breast', 889),
#  ('Greece', 888),
#  ('Singapore', 876),
#  ('Belgium', 872),
#  ('Jena,_Louisiana', 868),
#  ('BioShock', 860),
#  ('DNA', 850),
#  ('Anime', 847),
#  ('Albert_Einstein', 847),
#  ('The_Beatles', 846),
#  ('Habeas_corpus', 845),
#  ('Khmer_Rouge', 843),
#  ('Harry_Potter', 839),
#  ('IPod', 839),
#  ('Lars_Vilks_Muhammad_cartoons_controversy', 837),
#  ('UEFA_Champions_League', 836),
#  ('Philippines', 834),
#  ('Vietnam_War', 834),
#  ('Israel', 834),
#  ('WWE_Unforgiven', 834),
#  ('Land_of_Fire', 834),
#  ('Sasuke_Uchiha', 832),
#  ('Halloween', 829),
#  ('Lotus_Symphony', 826),
#  ('Hurricane_Katrina', 823),
#  ('Flying_Spaghetti_Monster', 821),
#  ('California', 818),
#  ('Evenness_of_zero', 817),
#  ('Picasso', 817),
#  ('Hentai', 817),
#  ('Renaissance', 814),
#  ('English_language', 814),
#  ('Windows_Vista', 813),
#  ('Abraham_Lincoln', 812),
#  ('List_of_Prison_Break_episodes', 812),
#  ('Led_Zeppelin', 808),
#  ('Lil_Wayne', 804),
#  ('Jenna_Jameson', 804),
#  ('Gossip_Girl', 804),
#  ('Batman', 803),
#  ('John_Cena', 802),
#  ('Test', 802),
#  ('List_of_traps_in_the_Saw_film_series', 801),
#  ('Jimi_Hendrix', 798),
#  ('The_buck_stops_here', 797),
#  ('New_Zealand', 797),
#  ('Iron_Man', 795),
#  ('Brett_Somers', 795),
#  ('Disk', 792),
#  ('Harry_Potter_and_the_Deathly_Hallows', 791),
#  ('Ronald_Goldman', 789),
#  ('Ultimate_Victory', 787),
#  ('Henry_VIII_of_England', 786),
#  ('Density', 785),
#  ('Pirates_versus_Ninjas', 785),
#  ('Mahatma_Gandhi', 777),
#  ('Leslie_Feist', 774),
#  ('Orgasm', 773),
#  ('Argentina', 773),
#  ('Paris', 772),
#  ('Greek_alphabet', 769),
#  ('Aristotle', 765),
#  ('Sparta', 762),
#  ('IPhone', 761),
#  ('Kim_Kardashian', 756),
#  ('Burj_Dubai', 754),
#  ('Chamillionaire', 753),
#  ('Prison_break', 751),
#  ('European_Union', 750),
#  ('Ernie_Chambers', 749),
#  ('BitTorrent', 748),
#  ('Human_resources', 747),
#  ('The_Undertaker', 743),
#  ('Netherlands', 741),
#  ('RAID', 737),
#  ('The_Simpsons', 733),
#  ('Family_guy', 733),
#  ('Historical_rankings_of_United_States_Presidents', 731),
#  ('High_School_Musical', 728),
#  ('Benjamin_Franklin', 723),
#  ('Fuck', 722),
#  ('Beowulf', 722),
#  ('Leave', 722),
#  ('Thanksgiving', 722),
#  ('Microsoft', 719),
#  ('Isaac_Newton', 716),
#  ('Michael_Jackson', 716),
#  ('United_States_Bill_of_Rights', 715),
#  ('Paris_Hilton', 712),
#  ('Clitoris', 712),
#  ('World_Trade_Center', 711),
#  ('List_of_Presidents_of_the_United_States', 708),
#  ('Ichigo_Kurosaki', 707),
#  ('Scientific_method', 707),
#  ('Akon', 707),
#  ('Triple_H', 705),
#  ('Psychology', 702),
#  ('Iran', 702),
#  ('Pol_Pot', 701),
#  ('Sally_Field', 699),
#  ('Sigmund_Freud', 696),
#  ('United_States_Declaration_of_Independence', 696),
#  ('Sioux', 696),
#  ('Eurocopter_Ecureuil', 695),
#  ('Resident_Evil', 695),
#  ('Galileo_Galilei', 693),
#  ('A_Memory_of_Light', 692),
#  ('Computer', 691),
#  ('Metallica', 689),
#  ('Turkey', 689),
#  ('Celebrity_sex_tape', 688),
#  ('Sweden', 686),
#  ('Dubai', 683),
#  ('Peru', 683),
#  ('Soulja_Boy', 682),
#  ('Elizabeth_I_of_England', 682),
#  ('Software_testing', 678),
#  ('Emoticon', 678),
#  ('Rome', 677),
#  ('Blog', 676),
#  ('Jesus', 672),
#  ('Plato', 671),
#  ('Heidi_Montag', 670),
#  ('Selena', 670),
#  ('Bleach', 668),
#  ('Hinduism', 668),
#  ('Andy_Warhol', 666),
#  ('Cat', 662),
#  ('Ethanol', 661),
#  ('Thomas_Jefferson', 661),
#  ('Dog', 661),
#  ('Democracy', 660),
#  ('conference_calls', 658),
#  ('Conference_calls', 658),
#  ('Playboy', 657),
#  ('Characters_in_the_Halo_series', 656),
#  ('Bioshock', 656),
#  ('John_Locke', 656),
#  ('Stuff', 654),
#  ('Greek_mythology', 653),
#  ('Hannah_Montana', 651),
#  ('The_Wheel_of_Time', 650),
#  ('Lana_Clarkson', 649),
#  ('Justin_Timberlake', 649),
#  ('Alexander_the_Great', 648),
#  ('Ashley_Tisdale', 646),
#  ('Cuba', 645),
#  ('Federal_funds_rate', 645),
#  ('New_Seven_Wonders_of_the_World', 644),
#  ('Evan_Rachel_Wood', 644),
#  ('Prime_number', 643),
#  ('World_of_Warcraft', 642),
#  ('Great_Depression', 641),
#  ('Chicago', 641),
#  ('Bipolar_disorder', 638),
#  ('Black_hole', 637),
#  ('Clitic', 634),
#  ('Religion', 634),
#  ('Animal', 633),
#  ('Nate_Hill', 633),
#  ('Battle_of_Thermopylae', 633),
#  ('Poland', 632),
#  ('World_in_Conflict', 631),
#  ('Marcia_Clark', 631),
#  ('Economics', 631),
#  ('Vietnam', 628),
#  ('Linux', 626),
#  ('Che_Guevara', 626),
#  ('Scotland', 625),
#  ('Randy_Orton', 624),
#  ('Moon', 621),
#  ('Julius_Caesar', 619),
#  ('Female_ejaculation', 618),
#  ('The_Hills', 617),
#  ('Britney_spears', 616),
#  ('Tropical_cyclone', 616),
#  ('Barry_Manilow', 615),
#  ('American_Revolution', 615),
#  ('Michelangelo', 614),
#  ('Chile', 614),
#  ('Globalization', 613),
#  ('Bill_Clinton', 612),
#  ('Johnnie_Cochran', 611),
#  ('Ten_Commandments', 610),
#  ('Router', 610),
#  ('United_Nations', 610),
#  ('North_America', 610),
#  ('Christianity', 610),
#  ('Tuberculosis', 610),
#  ('Pi', 608),
#  ('List_of_Scrubs_episodes', 608),
#  ('Volcano', 608),
#  ('South_Africa', 602),
#  ('Atomic_bombings_of_Hiroshima_and_Nagasaki', 600),
#  ('Switzerland', 600),
#  ('Gold', 600),
#  ('Judaism', 599),
#  ('Wood_Badge', 595),
#  ('Winston_Churchill', 594),
#  ('Charles_Darwin', 594),
#  ('List_of_South_Park_episodes', 594),
#  ('John_Lennon', 593),
#  ('Edgar_Allan_Poe', 593),
#  ('Chernobyl_disaster', 592),
#  ('George_Washington', 591),
#  ('Chris_Crocker', 590),
#  ('Timbaland', 589),
#  ('Indonesia', 589),
#  ('World_Wrestling_Entertainment_roster', 588),
#  ('PlayStation_Portable', 588),
#  ('Kakashi_Hatake', 587),
#  ('Thailand', 587),
#  ('List_of_dog_breeds', 585),
#  ('Korean_War', 585),
#  ('Asia', 585),
#  ('Operating_system', 584),
#  ('American_Revolutionary_War', 584),
#  ('Nicole_Scherzinger', 583),
#  ('Marketing', 583),
#  ('Hayden_Panettiere', 581),
#  ('Seven_deadly_sins', 581),
#  ('Amino_acid', 580),
#  ('Atom', 578),
#  ('New_York', 577),
#  ('Sun', 575),
#  ('ENTER', 574),
#  ('Null', 573),
#  ('Continent', 573),
#  ('List_of_Bleach_episodes', 571),
#  ('Dana_Plato', 571),
#  ('South_Park', 571),
#  ('Halo', 571),
#  ('Priscilla_Presley', 571),
#  ('Freemasonry', 569),
#  ('Pyramid_of_Senusret_I', 566),
#  ('Socrates', 564),
#  ('The_Sopranos', 564),
#  ('Amy_Winehouse', 564),
#  ('MMR_vaccine', 563),
#  ('Ancient_Egypt', 563),
#  ('Tokyo', 559),
#  ('Smiley', 559),
#  ('Communism', 558),
#  ('Protein', 558),
#  ('Quadratic_equation', 557),
#  ('Electroshock_gun', 557),
#  ('Seven_Wonders_of_the_World', 557),
#  ('List_of_Heroes_episodes', 556),
#  ('Doctor_Who', 556),
#  ('Anucha_Browne_Sanders', 555),
#  ('Hawaii', 554),
#  ('Malaysia', 554),
#  ('Evolution', 554),
#  ('Mars', 553),
#  ('Foo_Fighters', 552),
#  ('Human_penis_size', 552),
#  ('Elizabeth_II_of_the_United_Kingdom', 551),
#  ('Existentialism', 549),
#  ('Colombia', 549),
#  ('Lion', 549),
#  ('Jennifer_Lopez', 548),
#  ('Norway', 548),
#  ('Fellatio', 548),
#  ('Ku_Klux_Klan', 547),
#  ('Craigslist', 546),
#  ('Industrial_Revolution', 546),
#  ('Copper', 545),
#  ('Socialism', 545),
#  ('Friends', 544),
#  ('Jessica_Alba', 544),
#  ('Heroin', 543),
#  ('Native_Americans_in_the_United_States', 542),
#  ('List_of_The_Simpsons_episodes', 541),
#  ('Nudity', 541),
#  ('Steve_Jobs', 540),
#  ('SELENE', 540),
#  ('Miley_Cyrus', 539),
#  ('AIDS', 538),
#  ('Pink_Floyd', 538),
#  ('Paramore', 537),
#  ('Linkin_Park', 537),
#  ('Vulva', 537),
#  ('Angelina_Jolie', 536),
#  ('Human', 536),
#  ('Hong_Kong', 535),
#  ('List_of_Wii_games', 535),
#  ('Philosophy', 534),
#  ('Pluto', 534),
#  ('Abortion', 534),
#  ('Texas', 533),
#  ('One_Piece', 531),
#  ('Hedge_fund', 530),
#  ('Spanish_language', 529),
#  ('Alicia_Silverstone', 529),
#  ('Porn', 528),
#  ('Bob_Dylan', 527),
#  ('Antarctica', 527),
#  ('Music', 527),
#  ('Hydrogen', 527),
#  ('Marc_Ecko', 526),
#  ('Marilyn_Manson', 525),
#  ('Pregnancy', 524),
#  ('Cloverfield', 524),
#  ('List_of_House_episodes', 524),
#  ('Zodiac', 524),
#  ('Caffeine', 522),
#  ('Iraq', 522),
#  ('Metaphor', 522),
#  ('Dave_Bautista', 521),
#  ('Encyclopedia', 521),
#  ('Culture', 520),
#  ('Cold_War', 520),
#  ('Thomas_Edison', 519),
#  ('Schizophrenia', 517),
#  ('Earthquake', 517),
#  ('Aztec', 517),
#  ('Bacteria', 516),
#  ('Roman_Empire', 516),
#  ('Google_Earth', 516),
#  ('Ejaculation', 515),
#  ('Kanye_West_discography', 515),
#  ('Talk_like_a_pirate', 515),
#  ('Sam_Horrigan', 514),
#  ('List_of_H_anime', 513),
#  ('Muhammad', 513),
#  ('Luciano_Pavarotti', 512),
#  ('Ronald_Reagan', 512),
#  ('Criss_Angel', 512),
#  ('Glucose', 510),
#  ('Mesopotamia', 509),
#  ('Futurama', 509),
#  ('Main_page', 509),
#  ('Basketball', 508),
#  ('Great_Wall_of_China', 507),
#  ('Darfur_conflict', 506),
#  ('International_Phonetic_Alphabet', 506),
#  ('Normal_distribution', 505),
#  ('Kat_Von_D', 503),
#  ('Classical_element', 501),
#  ('RMS_Titanic', 501),
#  ('Guitar', 500),
#  ('Harry_potter', 500),
#  ('Mobile_phone', 499),
#  ('Ludwig_van_Beethoven', 499),
#  ('Absinthe', 498),
#  ('Bluetooth', 498),
#  ('University_of_Florida_Taser_incident', 498),
#  ('Columbine_High_School_massacre', 498),
#  ('Theodore_Roosevelt', 497),
#  ('Taj_Mahal', 497),
#  ('List_of_Saw_characters', 496),
#  ('Finland', 496),
#  ('Pakistan', 494),
#  ('Gimme_More', 494),
#  ('Serial_ATA', 493),
#  ('Virus', 492),
#  ('Clinical_depression', 492),
#  ('List_of_SpongeBob_SquarePants_episodes', 491),
#  ('Digimon', 490),
#  ('Robert_jordan', 490),
#  ('Wentworth_Miller', 490),
#  ('Physics', 490),
#  ('Christina_Aguilera', 489),
#  ('Grand_Theft_Auto_IV', 489),
#  ('Andrew_Meyer', 488),
#  ('Charles_Manson', 488),
#  ('Scrubs', 487),
#  ('The_Holocaust', 487),
#  ('Shawn_Michaels', 486),
#  ('MSN_Hotmail', 486),
#  ('Puritan', 485),
#  ('PH', 485),
#  ('Gettysburg_Address', 485),
#  ('Tsunami', 484),
#  ('Carbon_dioxide', 484),
#  ('Tiger', 484),
#  ('Iceland', 483),
#  ('Fall_Out_Boy', 483),
#  ('Pastafarian', 482),
#  ('Crips', 481),
#  ('Michael_Jordan', 481),
#  ('Jamaica', 480),
#  ('BDSM', 480),
#  ('Barack_Obama', 480),
#  ('Gwen_Stefani', 479),
#  ('Metric_system', 479),
#  ('Myanmar', 479),
#  ('Marie_Antoinette', 478),
#  ('Global_Positioning_System', 478),
#  ('Ecuador', 478),
#  ('Tina_Fey', 478),
#  ('Stone_Cold_Steve_Austin', 477),
#  ('Pokemon', 477),
#  ('Victoria_Beckham', 477),
#  ('Katherine_Heigl', 475),
#  ('Zeus', 475),
#  ('Karl_Marx', 474),
#  ('Fourteenth_Amendment_to_the_United_States_Constitution', 474),
#  ('Oxygen', 474),
#  ('Cancer', 473),
#  ('Speed_of_light', 473),
#  ('Nelson_Mandela', 473),
#  ('Thirteen_Colonies', 473),
#  ('American_football', 473),
#  ('Seven_Wonders_of_the_Ancient_World', 473),
#  ('Marilyn_Monroe', 472),
#  ('Information_technology', 472),
#  ('Lauren_Conrad', 471),
#  ('Jupiter', 471),
#  ('Suicide', 470),
#  ('Mario', 470),
#  ('Star_Wars', 469),
#  ('Science', 469),
#  ('Chris_Benoit', 469),
#  ('The_Great_Khali', 468),
#  ('Dave_Grohl', 468),
#  ('Tha_Carter_III', 467),
#  ('List_of_characters_in_Heroes', 467),
#  ('Cambodia', 466),
#  ('Independent_variable', 466),
#  ('Puerto_Rico', 466),
#  ('Martin_Luther', 465),
#  ('Spider', 464),
#  ('EBay', 464),
#  ('Lindsay_Lohan', 464),
#  ('Romania', 463),
#  ('Venezuela', 463),
#  ('French_Revolution', 462),
#  ('Hulk_Hogan', 462),
#  ('Manga', 461),
#  ('Jim_Carrey', 460),
#  ('Hotmail', 460),
#  ('Maya_civilization', 460),
#  ('Sean_Kingston', 459),
#  ('Elephant', 459),
#  ('Capital_punishment', 459),
#  ('Wolfgang_Amadeus_Mozart', 456),
#  ('XML', 455),
#  ('Age_of_Enlightenment', 455),
#  ('List_of_airlines', 454),
#  ('Inflation', 454),
#  ('Iron', 454),
#  ('James_Bond', 454),
#  ('Death_Note', 453),
#  ('Quentin_Tarantino', 453),
#  ('Jolly_Roger', 452),
#  ('Florida', 452),
#  ('Avril_Lavigne', 451),
#  ('Federal_Reserve_System', 450),
#  ('UCLA_Taser_incident', 450),
#  ('DVD', 450),
#  ('Scientology', 449),
#  ('Kekkei_genkai', 448),
#  ('Corporal_punishment', 448),
#  ('Cell_membrane', 448),
#  ('Taiwan', 448),
#  ('Carbon', 448),
#  ('Solar_System', 448),
#  ('Blood_pressure', 447),
#  ('Domain_name_system', 447),
#  ('My_Chemical_Romance', 447),
#  ('Database', 447),
#  ('Bugatti_Veyron', 447),
#  ('Final_Fantasy_VII', 446),
#  ('Sid_Vicious', 446),
#  ('Multiple_sclerosis', 446),
#  ('Mona_Lisa', 446),
#  ('Shanghai', 445),
#  ('Warren_Buffett', 445),
#  ('Enzyme', 445),
#  ('Arnold_Schwarzenegger', 445),
#  ('Project_management', 444),
#  ('Copyright', 444),
#  ('Neil_Armstrong', 444),
#  ('Bob_Marley', 444),
#  ('Guitar_Hero_II', 444),
#  ('List_of_countries_by_population', 443),
#  ('South_America', 442),
#  ('Capitalism', 442),
#  ('Plate_tectonics', 442),
#  ('Diabetes', 442),
#  ('Sociology', 441),
#  ('Ernest_Hemingway', 440),
#  ('Anthropology', 440),
#  ('Dominican_Republic', 440),
#  ('Johnny_Depp', 440),
#  ('Mafia', 439),
#  ('Autumn', 439),
#  ('Sarah_Silverman', 439),
#  ('Napoleon_I_of_France', 439),
#  ('WiFi', 438),
#  ('Dragon_Ball_Z', 438),
#  ('Apple', 438),
#  ('Illuminati', 437),
#  ('International_Talk_Like_A_Pirate_Day', 437),
#  ('RAM', 437),
#  ('List_of_tallest_buildings_and_structures_in_the_world', 437),
#  ('The_office', 436),
#  ('A', 435),
#  ('Middle_Ages', 434),
#  ('Stem_cell', 434),
#  ('Nas', 434),
#  ('Cristiano_Ronaldo', 433),
#  ('Black_Death', 433),
#  ('Nigeria', 433),
#  ('Bret_Michaels', 433),
#  ('Naegleria_fowleri', 433),
#  ('World_Wide_Web', 432),
#  ('Lebanon', 432),
#  ('Nitrogen', 432),
#  ('Portugal', 432),
#  ('Google_Maps', 431),
#  ('Supreme_Court_of_the_United_States', 431),
#  ('Lil_wayne', 431),
#  ('Real_Madrid', 431),
#  ('Horse', 431),
#  ('Skull_and_bones', 430),
#  ('Radiohead', 430),
#  ('Bruce_Lee', 430),
#  ('David_Beckham', 430),
#  ('Agnosticism', 429),
#  ('List_of_Naruto_episodes', 429),
#  ('FC_Barcelona', 429),
#  ('Diamond', 429),
#  ('Greek_gods', 429),
#  ('Wales', 429),
#  ('Wolf', 428),
#  ('Jazz', 428),
#  ('Saudi_Arabia', 427),
#  ('Windows_XP', 427),
#  ('Glen_Jacobs', 427),
#  ('Biology', 426),
#  ('Big_Bang', 426),
#  ('Latin', 425),
#  ('Computer_virus', 425),
#  ('Cunnilingus', 425),
#  ('World_War_Hulk', 425),
#  ('Oprah_Winfrey', 424),
#  ('Zodiac_Killer', 424),
#  ('Muhammad_Ali', 424),
#  ('Microsoft_Windows', 424),
#  ('Chris_Brown', 423),
#  ('Advertising', 423),
#  ('Death_of_Superman', 423),
#  ('Fish', 423),
#  ('Alaska', 422),
#  ('Disappearance_of_Madeleine_McCann', 422),
#  ('Project_Runway', 422),
#  ('Ukraine', 422),
#  ('Eye_color', 421),
#  ('Soviet_Union', 421),
#  ('Ancient_Rome', 420),
#  ('OSI_model', 420),
#  ('Television', 420),
#  ('Richard_Nixon', 419),
#  ('French_language', 419),
#  ('Friedrich_Nietzsche', 419),
#  ('Fibonacci_number', 419),
#  ('Heart', 419),
#  ('USB', 419),
#  ('IQ', 418),
#  ('Korn', 418),
#  ('Perez_Hilton', 418),
#  ('Communication', 418),
#  ('Stalin', 418),
#  ('Osama_bin_Laden', 417),
#  ('Dolphin', 417),
#  ('Bukkake', 417),
#  ('List_of_Marvel_Comics_characters', 417),
#  ('Afghanistan', 417),
#  ('Greenland', 416),
#  ('Nintendo', 415),
#  ('Joan_of_Arc', 415),
#  ('Romanticism', 415),
#  ('Charlie_Chaplin', 415),
#  ('Autumnal_Equinox_Day', 415),
#  ('Website', 415),
#  ('Six_Sigma', 414),
#  ('Derivative', 414),
#  ('Tattoo', 414),
#  ('Tailed_beasts', 414),
#  ('Chemistry', 414),
#  ('Iraq_War', 413),
#  ('Frida_Kahlo', 413),
#  ('IP_address', 413),
#  ('Apollo', 411),
#  ('Nintendo_DS', 411),
#  ('Stonehenge', 411),
#  ('Alfred_Hitchcock', 411),
#  ('James_Bruce_Round_Barn', 411),
#  ('South_Korea', 411),
#  ('Obesity', 410),
#  ('The_View', 410),
#  ('Aluminium', 410),
#  ('Zeitgeist', 410),
#  ('Austria', 409),
#  ('Ipod', 409),
#  ('GDP', 409),
#  ('Pneumonia', 409),
#  ('Charmed', 409),
#  ('List_of_Bleach_characters', 409),
#  ('Venus', 408),
#  ('Machu_Picchu', 408),
#  ('Search_engine', 408),
#  ('Ottoman_Empire', 408),
#  ('Nanotechnology', 408),
#  ('Alcohol', 407),
#  ('Taser', 407),
#  ('United_States_dollar', 406),
#  ('Methamphetamine', 406),
#  ('Gudgeonville_Covered_Bridge', 406),
#  ('Ethiopia', 406),
#  ('Gaara', 406),
#  ('Statistics', 405),
#  ('Land_of_Sound', 405),
#  ('Enterprise_resource_planning', 404),
#  ('Ammonia', 404),
#  ('Erik_Prince', 404),
#  ('Paper_size', 404),
#  ('Sakura_Haruno', 404),
#  ('First_Amendment', 404),
#  ('Morocco', 404),
#  ('Red_Hot_Chili_Peppers', 404),
#  ('Mother_Teresa', 403),
#  ('Magna_Carta', 402),
#  ('James_Blunt', 402),
#  ('Baseball', 402),
#  ('Sex_Pistols', 402),
#  ('Frank_Sinatra', 402),
#  ('Kimora_Lee_Simmons', 401),
#  ('HDMI', 401),
#  ('Circumcision', 401),
#  ('Haiku', 401),
#  ('Homosexuality', 400),
#  ('Jane_Austen', 400),
#  ('Photosynthesis', 400),
#  ('Milo_Ventimiglia', 400),
#  ('Mexico_City', 399),
#  ('Smallville', 398),
#  ('Croatia', 398),
#  ('Articles_of_Confederation', 398),
#  ('Toronto', 398),
#  ('Chemical_element', 398),
#  ('Shark', 398),
#  ('Death', 396),
#  ('Hard_disk_drive', 396),
#  ('Ron_Paul', 396),
#  ('Subprime_lending', 396),
#  ('Denmark', 395),
#  ('Gmail', 395),
#  ('Malcolm_X', 395),
#  ('Recession', 395),
#  ('Population', 395),
#  ('God', 394),
#  ('Vince_McMahon', 394),
#  ('Tornado', 393),
#  ('Hilary_Duff', 393),
#  ('Robert_Kardashian', 393),
#  ('Ivy_League', 393),
#  ('French_and_Indian_War', 392),
#  ('United_States_House_of_Representatives', 392),
#  ('Ancient_Greece', 392),
#  ('Before_I_Self_Destruct', 391),
#  ('SpongeBob_SquarePants', 391),
#  ('List_of_major_Konoha_teams', 391),
#  ('Ferdinand_Magellan', 391),
#  ('Roman_Catholic_Church', 390),
#  ('HIV', 390),
#  ('The_Biggest_Loser', 390),
#  ('Scientific_classification', 390),
#  ('Sodium', 390),
#  ('Rage_Against_the_Machine', 390),
#  ('Acetic_acid', 390),
#  ('Charles_Dickens', 389),
#  ('Hydrocodone', 389),
#  ('Godzilla', 388),
#  ('House', 388),
#  ('Steel', 388),
#  ('Daft_Punk', 388),
#  ('Racism', 388),
#  ('Kim_Novak', 387),
#  ('Shakira', 387),
#  ('Wwe', 387),
#  ('Naruto_geography', 387),
#  ('Shock_site', 387),
#  ('List_of_songs_in_Guitar_Hero_II', 387),
#  ('Ethernet', 387),
#  ('Kama_Sutra', 386),
#  ('Pollution', 386),
#  ('Nuclear_power', 385),
#  ('Iron_Maiden', 385),
#  ('Snoop_Dogg', 385),
#  ('Cricket', 385),
#  ('Great_Pyramid_of_Giza', 385),
#  ('Coffee', 383),
#  ('Beauty_and_the_geek', 383),
#  ('Ethics', 383),
#  ('Pennsylvania', 383),
#  ('WiMAX', 383),
#  ('Second_Amendment_to_the_United_States_Constitution', 382),
#  ('Mount_Everest', 382),
#  ('Customer_relationship_management', 382),
#  ('Leet', 382),
#  ('Jodie_Foster', 382),
#  ('Manhattan', 381),
#  ('Viscosity', 381),
#  ('United_Arab_Emirates', 381),
#  ('Art', 381),
#  ('Tank_Johnson', 380),
#  ('Venice', 380),
#  ('Brain', 379),
#  ('Foo_fighters', 379),
#  ('Dictionary', 378),
#  ('Kyoto_Protocol', 378),
#  ('List_of_unusual_deaths', 378),
#  ('Ben_Bernanke', 377),
#  ('Computer_network', 377),
#  ('Statue_of_Liberty', 377),
#  ('Columbus_Day', 377),
#  ('Late_Registration', 377),
#  ('Golden_ratio', 376),
#  ('Sodium_hydroxide', 376),
#  ('Sodomy', 376),
#  ('Swastika', 376),
#  ('The_Crucible', 376),
#  ('Neighbours', 376),
#  ('Kurt_Cobain', 376),
#  ('Voltaire', 375),
#  ('Ayn_Rand', 375),
#  ('Fidel_Castro', 375),
#  ('Mathematics', 375),
#  ('Youtube', 374),
#  ('NATO', 374),
#  ('Nelly', 374),
#  ('Praying_mantis', 374),
#  ('Victoria_of_the_United_Kingdom', 373),
#  ('David_Bowie', 373),
#  ('Phishing', 373),
#  ('Photography', 373),
#  ('Fullmetal_Alchemist', 372),
#  ('All_your_base_are_belong_to_us', 372),
#  ('Bangladesh', 372),
#  ('New_England', 372),
#  ('Slavery', 372),
#  ('Sulfur', 372),
#  ('Bloods', 371),
#  ('Hungary', 371),
#  ('Rock_of_Love_with_Bret_Michaels', 371),
#  ('Mass', 371),
#  ('Jeff_Hardy', 371),
#  ('The_Death_of_Superman', 371),
#  ('Punk_rock', 370),
#  ('Eiffel_Tower', 370),
#  ('Amanda_Bynes', 370),
#  ('MapQuest', 369),
#  ('Sherri_Shepherd', 369),
#  ('Meningitis', 369),
#  ('The_White_Stripes', 369),
#  ('We_Are_Marshall', 369),
#  ('Hitler', 369),
#  ('Ryan_Sheckler', 369),
#  ('Steve_Fossett', 368),
#  ('Virginia_Tech_massacre', 368),
#  ('Bible', 367),
#  ('Solar_power', 367),
#  ('Anemia', 367),
#  ('Alexander_Graham_Bell', 367),
#  ('Unified_Modeling_Language', 366),
#  ('Entropy', 366),
#  ('Hydrochloric_acid', 365),
#  ('Marijuana', 365),
#  ('Milky_Way', 365),
#  ('Fascism', 364),
#  ('Aerosmith', 364),
#  ('Education', 364),
#  ('Condom', 364),
#  ('New_Jersey', 363),
#  ('Naruto_ninja_ranks', 363),
#  ('Energy', 363),
#  ('Rape', 363),
#  ('Eddie_Vedder', 363),
#  ('Blood_type', 362),
#  ('Blackwater', 362),
#  ('Ghana', 362),
#  ('List_of_One_Piece_episodes', 362),
#  ('Sudoku', 362),
#  ('List_of_gay_porn_stars', 361),
#  ('Zsa_Zsa_Gabor', 361),
#  ('Sylar', 361),
#  ('John_Kerry', 361),
#  ('Oldest_people', 361),
#  ('The_Divine_Comedy', 361),
#  ('Plant', 361),
#  ('Snake', 361),
#  ('Serj_Tankian', 361),
#  ('Autofellatio', 361),
#  ('Dylan_Postl', 360),
#  ('Paul_McCartney', 360),
#  ('HTML', 360),
#  ('Malaria', 360),
#  ('Freddie_Mercury', 360),
#  ('Thomas_Hobbes', 360),
#  ('List_of_Naruto_story_arcs', 360),
#  ('Eric_Clapton', 359),
#  ('British_Empire', 359),
#  ('Lost', 359),
#  ('Oscar_Wilde', 358),
#  ('Achilles', 358),
#  ('Guatemala', 358),
#  ('Colosseum', 358),
#  ('Ali_Larter', 358),
#  ('Desert', 358),
#  ('Hip_hop_music', 358),
#  ('Crusades', 357),
#  ('Sexually_transmitted_disease', 357),
#  ('FireWire', 357),
#  ('Football', 357),
#  ('Human_anatomy', 357),
#  ('Al_Capone', 357),
#  ('Kenya', 356),
#  ('None', 356),
#  ('Correlation', 356),
#  ('ITIL', 355),
#  ('Boston_Tea_Party', 355),
#  ('Constitution', 355),
#  ('Justice_League_Unlimited', 355),
#  ('Vampire', 355),
#  ('Kazakhstan', 355),
#  ('Ninja', 355),
#  ('Samurai', 354),
#  ('Ocean', 354),
#  ('Attack_on_Pearl_Harbor', 354),
#  ('Chess', 353),
#  ('Oxycodone', 353),
#  ('Mitochondrion', 353),
#  ('Hypertension', 352),
#  ('Massachusetts', 352),
#  ('Athena', 352),
#  ('Meteorite', 352),
#  ('Seinfeld', 351),
#  ('Ugly_Betty', 351),
#  ('Saturn', 351),
#  ('Jordan', 351),
#  ('Lesbian', 350),
#  ('Rock_Lee', 350),
#  ('Avatar', 349),
#  ('Technology', 349),
#  ('Trigonometric_function', 349),
#  ('List_of_social_networking_websites', 349),
#  ('Dragon', 349),
#  ('Ludacris', 349),
#  ('Federalism', 349),
#  ('Chlorine', 349),
#  ('Wonders_of_the_World', 348),
#  ('Oktoberfest', 348),
#  ('Skype', 348),
#  ('Taoism', 348),
#  ('List_of_Heroes_graphic_novels', 347),
#  ('The_College_Dropout', 347),
#  ('Republic_of_Ireland', 347),
#  ('Vincent_van_Gogh', 347),
#  ('Paradox', 347),
#  ('Land_of_Wind', 347),
#  ('Haiti', 347),
#  ('Nikola_Tesla', 346),
#  ('Athens', 346),
#  ('South_park', 345),
#  ('LSD', 345),
#  ('Pubic_hair', 345),
#  ('United_States_Marine_Corps', 345),
#  ('Pop_art', 345),
#  ('Anorexia_nervosa', 345),
#  ('Indiana_Jones_and_the_Kingdom_of_the_Crystal_Skull', 344),
#  ('WWE_Cyber_Sunday', 344),
#  ('Aphrodite', 344),
#  ('Mark_Twain', 344),
#  ('Lead', 344),
#  ...]

# %%
def get_time_distribution(file_name):
    times=[]
    for line in open(file_name):
        t=(float(line.strip().split(' ')[1])-1188604800.0)//3600
#         t=datetime.fromtimestamp(t)
#         print(t)
        times.append(t)
    return times

# %%
import multiprocessing.dummy

# %%
hour_dict=dict()
p = multiprocessing.dummy.Pool(4)
filenames=os.listdir('./data/only_lemma/')
paths=['./data/only_lemma/%s'%filename for filename in filenames]
step=10
for filename in tqdm(paths):
    times=get_time_distribution(filename)
    for t in times:
        hour=t
        try:
            hour_dict[hour]+=1
        except:
            hour_dict[hour]=1
# Out:
# HBox(children=(IntProgress(value=0, max=792), HTML(value='')))
# Exception in thread Thread-112:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/home/xuanli2/penv/lib/python3.5/site-packages/tqdm/_monitor.py", line 62, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/xuanli2/penv/lib/python3.5/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-17d06a5d4a52> in <module>()
#       7     times=get_time_distribution(filename)
#       8     for t in times:
# ----> 9         hour=t//3600
#      10         try:
#      11             hour_dict[hour]+=1
#
# KeyboardInterrupt:

# %%
len(hour_dict)
# Out:
# 1

# %%
def show_time_curve(time_serial, xlabel, ylabel, title):
    count=list(time_serial.items())
    count=sorted(count, key=lambda x:x[0])
    x,y=[],[]
    for xx,yy in count:
        x.append(xx)
        y.append(yy)
    plt.figure(figsize=(10,7))
    plt.plot(x,y)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid()
    plt.show()

# %%
start_time=datetime.strptime('2007-09-01 00:00:00', "%Y-%m-%d %H:%M:%S")
start_time.timestamp()
# Out:
# 1188604800.0

# %%
show_time_curve(hour_dict, 'Passed Hour', 'Frequency','HHHH')

# %%
filtered_passed_hour=list(filter(lambda x:x//24>=18 and x//24<=28,passed_hour))

# %%
c

# %%
filtered_passed_day=filtered_passed_hour//24

# %%
show_time_curve(filtered_passed_hour, 'Hour', 'Visit Count', 'Visit # v.s. Passed hours')
show_time_curve(filtered_passed_day, 'Day', 'Visit Count', 'Visit # v.s. Passed day')

# %%
visit_per_hour_one_day=filtered_passed_hour%24

# %%
show_time_curve(visit_per_hour_one_day, 'Hour', 'Visit Count', 'Visit # v.s. Passed hours')
